# %% [markdown]
# <a href="https://colab.research.google.com/github/Owino-Paul/Learn_Git/blob/master/Python_Data_Cleaning_Basics_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **REMEMBER TO MAKE A COPY OF THE NOTEBOOK BEFORE YOU START WORKING ON IT.**

# %% [markdown]
# # Python Data Cleaning: Basics

# %% [markdown]
# ## Step 1: Finding and counting missing data

# %% [markdown]
# Having known how missing values in a dataset are created, we will now get introduced to how we can work with such a dataset. The first step that we will perform is to find the missing values and know how many they are.

# %%
# We will first import our dataset that we will use for the examples. We will do this by first
# Importing our pandas library
import pandas as pd

# %%
# Challenge 1
# In parallel to this, we will also be working with another dataset too. We will use it for practice.
# Let's first store our url location just like we did above
gov_dataset = 'http://bit.ly/GovProjectFinanceDataset1'

# Then read the dataset from url and store it in our variable of choice
gov_dataset = pd.read_csv('http://bit.ly/GovProjectFinanceDataset1')
gov_dataset.head()
# Out:
#                                  Implementing_Agency  \
# 0                                                NaN
# 1   MOEW&NR  National Environment Management Auth...
# 2   Ministry of Agriculture, Livestock and Fisheries
# 3                                     The Presidency
# 4   MOAL&F  Kenya  Plant Health Inspectorate Serv...
#
#    Total_-_GOK_Budget_Est_KES  Total_-_Loan_Budget_Est_KES  \
# 0                0.000000e+00                            0
# 1                0.000000e+00                            0
# 2                2.306364e+09                  23354779585
# 3                         NaN                            0
# 4                0.000000e+00                            0
#
#    Total_-_Grant_Budget_Est_KES  Total_Budget_Supported__by_Donors_KES  \
# 0                    3524395000                             3524395000
# 1                     300000000                              300000000
# 2                    8732081258                            32086860843
# 3                             0                                      0
# 4                      66916163                               66916163
#
#    Total_2013/2014_Budget_KES  OBJECTID
# 0                  3524395000         0
# 1                   300000000         1
# 2                 34393225231         2
# 3                           0         3
# 4                    66916163         4

# %%
# dataset info
gov_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Implementing_Agency                    39 non-null     object
#  1   Total_-_GOK_Budget_Est_KES             39 non-null     float64
#  2   Total_-_Loan_Budget_Est_KES            40 non-null     int64
#  3   Total_-_Grant_Budget_Est_KES           40 non-null     int64
#  4   Total_Budget_Supported__by_Donors_KES  40 non-null     int64
#  5   Total_2013/2014_Budget_KES             40 non-null     int64
#  6   OBJECTID                               40 non-null     int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 2.3+ KB

# %%
# Describign our dataset
gov_dataset.describe()
# Out:
#        Total_-_GOK_Budget_Est_KES  Total_-_Loan_Budget_Est_KES  \
# count                3.900000e+01                 4.000000e+01
# mean                 2.679713e+09                 1.139711e+10
# std                  7.145662e+09                 3.132677e+10
# min                  0.000000e+00                 0.000000e+00
# 25%                  2.096625e+06                 0.000000e+00
# 50%                  4.011780e+07                 0.000000e+00
# 75%                  1.108021e+09                 5.131401e+09
# max                  3.003600e+10                 1.493200e+11
#
#        Total_-_Grant_Budget_Est_KES  Total_Budget_Supported__by_Donors_KES  \
# count                  4.000000e+01                           4.000000e+01
# mean                   4.439625e+09                           1.583673e+10
# std                    9.714505e+09                           3.638301e+10
# min                    0.000000e+00                           0.000000e+00
# 25%                    0.000000e+00                           0.000000e+00
# 50%                    9.500000e+07                           2.477000e+08
# 75%                    2.567208e+09                           1.050192e+10
# max                    4.090251e+10                           1.748060e+11
#
#        Total_2013/2014_Budget_KES   OBJECTID
# count                4.000000e+01  40.000000
# mean                 1.844794e+10  19.500000
# std                  4.044882e+10  11.690452
# min                  0.000000e+00   0.000000
# 25%                  6.922904e+07   9.750000
# 50%                  1.309622e+09  19.500000
# 75%                  1.078605e+10  29.250000
# max                  2.010550e+11  39.000000

# %%
# We count the number of non - missing values in the df dataframe.
gov_dataset.count()
# Out:
# Implementing_Agency                      39
# Total_-_GOK_Budget_Est_KES               39
# Total_-_Loan_Budget_Est_KES              40
# Total_-_Grant_Budget_Est_KES             40
# Total_Budget_Supported__by_Donors_KES    40
# Total_2013/2014_Budget_KES               40
# OBJECTID                                 40
# dtype: int64

# %%
# Finding null values
gov_dataset.isnull().sum()
# Out:
# Implementing_Agency                      1
# Total_-_GOK_Budget_Est_KES               1
# Total_-_Loan_Budget_Est_KES              0
# Total_-_Grant_Budget_Est_KES             0
# Total_Budget_Supported__by_Donors_KES    0
# Total_2013/2014_Budget_KES               0
# OBJECTID                                 0
# dtype: int64

# %%
# A longer method can be to subtract the no. of non-missing rows from the total number

# of rows in the dataframe in order to determine the no. of missing values as shown
# Out:
# Number of missing rows: 2

# %%
# Challenge 3: Government Project Dataset
# We now also subtract the no. of non-missing rows from the total number of rows to determine the no. of missing values in our government project dataset
# Total number of rows
total_rows = gov_dataset.shape[0]

# Number of non-missing rows
non_missing_rows = gov_dataset.dropna().shape[0]

# Number of missing rows
missing_rows = total_rows - non_missing_rows

print(f"Number of missing rows: {missing_rows}")

# %%
# Another method would also be to count the number of missing values in our dataframe,
# using the count_nonzero function from numpy - and including the isnull() method.

# But before we do that, we would need import numpy,
import numpy as np

# Count missing values
missing_values_count = np.count_nonzero(gov_dataset.isnull())

print(f"Total missing values in the dataset: {missing_values_count}")
# Out:
# Total missing values in the dataset: 2

# %%
# Challenge 4: Government Project Dataset
# Let's just do what we did in our previous cell. We found out the number of missing values in our dataset using the count_nonzero function from numpy

# Count missing values
missing_values_count = np.count_nonzero(gov_dataset.isnull())

print(f"Total missing values in the dataset: {missing_values_count}")
# Out:
# Total missing values in the dataset: 2

# %%
# We could also count the number of missing values for a particular column by specifying
# the column by still using the count_nonzero function from numpy
missing_values_column = np.count_nonzero(gov_dataset['Implementing_Agency'].isnull())

print(f"Total missing values in column 'Implementing_Agency': {missing_values_column}")
# Out:
# Total missing values in column 'Implementing_Agency': 1

# %%
# Specify the columns you want to check
columns_to_check = ['Implementing_Agency', 'Total_-_GOK_Budget_Est_KES']

# Count missing values in the selected columns
missing_values_per_column = gov_dataset[columns_to_check].isnull().sum()

print(missing_values_per_column)
# Out:
# Implementing_Agency           1
# Total_-_GOK_Budget_Est_KES    1
# dtype: int64

# %%
# Challenge 5: Government Project Dataset
# And again specify how many non-missing values we have in the column: Total_-_GOK_Budget_Est_KES

missing_values_column1 = np.count_nonzero(gov_dataset['Total_-_GOK_Budget_Est_KES'].isnull())

print(f"Total missing values in column 'Total_-_GOK_Budget_Est_KES': {missing_values_column1}")
# Out:
# Total missing values in column 'Total_-_GOK_Budget_Est_KES': 1

# %% [markdown]
# ## Step 2: Clean Missing Data

# %% [markdown]
# Now that we have been able to identify our missing values in our datasets, we can deal with them in the following ways.

# %% [markdown]
# ### a) We can recode/replace these values
# Here, we can do this by using the fillna method and recoding/replacing the missing values with another value or other values. In this example, we will recode the missing values to 0.

# %%
# We can recode missing values with 0 by doing the following.
# Do note that this will appear as 0.0 in your dataframe.
#
gov_dataset_recode = gov_dataset.fillna(0)

# then preview the first 5 rows for the recoded dataframe
gov_dataset_recode.head(5)
# Out:
#                                  Implementing_Agency  \
# 0                                                  0
# 1   MOEW&NR  National Environment Management Auth...
# 2   Ministry of Agriculture, Livestock and Fisheries
# 3                                     The Presidency
# 4   MOAL&F  Kenya  Plant Health Inspectorate Serv...
#
#    Total_-_GOK_Budget_Est_KES  Total_-_Loan_Budget_Est_KES  \
# 0                0.000000e+00                            0
# 1                0.000000e+00                            0
# 2                2.306364e+09                  23354779585
# 3                0.000000e+00                            0
# 4                0.000000e+00                            0
#
#    Total_-_Grant_Budget_Est_KES  Total_Budget_Supported__by_Donors_KES  \
# 0                    3524395000                             3524395000
# 1                     300000000                              300000000
# 2                    8732081258                            32086860843
# 3                             0                                      0
# 4                      66916163                               66916163
#
#    Total_2013/2014_Budget_KES  OBJECTID
# 0                  3524395000         0
# 1                   300000000         1
# 2                 34393225231         2
# 3                           0         3
# 4                    66916163         4

# %%
# After recoding, let's check for non-missing values in the recoded dataframe
gov_dataset_recode.isnull().sum()
# Out:
# Implementing_Agency                      0
# Total_-_GOK_Budget_Est_KES               0
# Total_-_Loan_Budget_Est_KES              0
# Total_-_Grant_Budget_Est_KES             0
# Total_Budget_Supported__by_Donors_KES    0
# Total_2013/2014_Budget_KES               0
# OBJECTID                                 0
# dtype: int64

# %%
# let's check it's info
gov_dataset_recode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Implementing_Agency                    40 non-null     object
#  1   Total_-_GOK_Budget_Est_KES             40 non-null     float64
#  2   Total_-_Loan_Budget_Est_KES            40 non-null     int64
#  3   Total_-_Grant_Budget_Est_KES           40 non-null     int64
#  4   Total_Budget_Supported__by_Donors_KES  40 non-null     int64
#  5   Total_2013/2014_Budget_KES             40 non-null     int64
#  6   OBJECTID                               40 non-null     int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 2.3+ KB

# %% [markdown]
# **Challenge 7:** Together with your peer now discuss the cases where you might use the above recoding technique.

# %% [markdown]
# ### b) We can fill forward missing values

# %% [markdown]
# When data is filled data forward, the last known value is used for the next missing value. The missing values are replaced with the last known/recorded value. Let's see how that works.

# %%
# And now let's fill forward
#
gov_dataset_fill_forward = gov_dataset.fillna(method='ffill')

# Then preview our dataframe and try to understand it
gov_dataset_fill_forward.head(10)
# Out:
# <ipython-input-33-c4e866653026>:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   gov_dataset_fill_forward = gov_dataset.fillna(method='ffill')
#                                  Implementing_Agency  \
# 0                                                NaN
# 1   MOEW&NR  National Environment Management Auth...
# 2   Ministry of Agriculture, Livestock and Fisheries
# 3                                     The Presidency
# 4   MOAL&F  Kenya  Plant Health Inspectorate Serv...
# 5                        Ministry of Foreign Affairs
# 6     MRDA  Ewaso Ngiro North Dev. Authority (ENNDA)
# 7   MOE&P  Kenya Electricity Transmission Company...
# 8   Office of The Attorney General and Department...
# 9                 State Department of Infrastructure
#
#    Total_-_GOK_Budget_Est_KES  Total_-_Loan_Budget_Est_KES  \
# 0                0.000000e+00                            0
# 1                0.000000e+00                            0
# 2                2.306364e+09                  23354779585
# 3                2.306364e+09                            0
# 4                0.000000e+00                            0
# 5                0.000000e+00                            0
# 6                6.560292e+09                            0
# 7                0.000000e+00                   1304000000
# 8                0.000000e+00                            0
# 9                1.227000e+07                            0
#
#    Total_-_Grant_Budget_Est_KES  Total_Budget_Supported__by_Donors_KES  \
# 0                    3524395000                             3524395000
# 1                     300000000                              300000000
# 2                    8732081258                            32086860843
# 3                             0                                      0
# 4                      66916163                               66916163
# 5                      46000000                               46000000
# 6                             0                                      0
# 7                             0                             1304000000
# 8                    1351905890                             1351905890
# 9                             0                                      0
#
#    Total_2013/2014_Budget_KES  OBJECTID
# 0                  3524395000         0
# 1                   300000000         1
# 2                 34393225231         2
# 3                           0         3
# 4                    66916163         4
# 5                    46000000         5
# 6                  6560292000         6
# 7                  1304000000         7
# 8                  1351905890         8
# 9                    12270000         9

# %% [markdown]
# **Challenge 9: **Together with your peer discuss the cases where you might use the above fill forward technique.

# %% [markdown]
# ### c) We can fill backward missing values

# %% [markdown]
# We can also do the opposite, and fill data backward our missing values. When doing this, the newest value replaces the missing data.

# %%
# Again first lets preview df (last 10 items), and note the missing data in the boat and body columns
gov_dataset_fill_backward = gov_dataset.fillna(method='bfill')

# Then preview our dataframe and try to understand it
gov_dataset_fill_backward.head(10)
# Out:
# <ipython-input-34-2702321f9eaf>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   gov_dataset_fill_backward = gov_dataset.fillna(method='bfill')
#                                  Implementing_Agency  \
# 0   MOEW&NR  National Environment Management Auth...
# 1   MOEW&NR  National Environment Management Auth...
# 2   Ministry of Agriculture, Livestock and Fisheries
# 3                                     The Presidency
# 4   MOAL&F  Kenya  Plant Health Inspectorate Serv...
# 5                        Ministry of Foreign Affairs
# 6     MRDA  Ewaso Ngiro North Dev. Authority (ENNDA)
# 7   MOE&P  Kenya Electricity Transmission Company...
# 8   Office of The Attorney General and Department...
# 9                 State Department of Infrastructure
#
#    Total_-_GOK_Budget_Est_KES  Total_-_Loan_Budget_Est_KES  \
# 0                0.000000e+00                            0
# 1                0.000000e+00                            0
# 2                2.306364e+09                  23354779585
# 3                0.000000e+00                            0
# 4                0.000000e+00                            0
# 5                0.000000e+00                            0
# 6                6.560292e+09                            0
# 7                0.000000e+00                   1304000000
# 8                0.000000e+00                            0
# 9                1.227000e+07                            0
#
#    Total_-_Grant_Budget_Est_KES  Total_Budget_Supported__by_Donors_KES  \
# 0                    3524395000                             3524395000
# 1                     300000000                              300000000
# 2                    8732081258                            32086860843
# 3                             0                                      0
# 4                      66916163                               66916163
# 5                      46000000                               46000000
# 6                             0                                      0
# 7                             0                             1304000000
# 8                    1351905890                             1351905890
# 9                             0                                      0
#
#    Total_2013/2014_Budget_KES  OBJECTID
# 0                  3524395000         0
# 1                   300000000         1
# 2                 34393225231         2
# 3                           0         3
# 4                    66916163         4
# 5                    46000000         5
# 6                  6560292000         6
# 7                  1304000000         7
# 8                  1351905890         8
# 9                    12270000         9

# %% [markdown]
# **Challenge 11: ** Together with your peer discuss the cases where you might use the above fill backward technique.

# %% [markdown]
# ### d) We can interpolate missing values

# %% [markdown]
# Interpolation uses other values to fill in the missing values. It does this by treating missing values as if they should be equally spaced apart. This function fills in the missing values linearly as shown in the example below.

# %%
# Once again first lets print out gov_dataset, and note the missing data in the boat and body columns
# NB: iloc gets rows (or columns) at particular positions in the index
gov_dataset.iloc[0:10]
# Out:
#                                  Implementing_Agency  \
# 0                                                NaN
# 1   MOEW&NR  National Environment Management Auth...
# 2   Ministry of Agriculture, Livestock and Fisheries
# 3                                     The Presidency
# 4   MOAL&F  Kenya  Plant Health Inspectorate Serv...
# 5                        Ministry of Foreign Affairs
# 6     MRDA  Ewaso Ngiro North Dev. Authority (ENNDA)
# 7   MOE&P  Kenya Electricity Transmission Company...
# 8   Office of The Attorney General and Department...
# 9                 State Department of Infrastructure
#
#    Total_-_GOK_Budget_Est_KES  Total_-_Loan_Budget_Est_KES  \
# 0                0.000000e+00                            0
# 1                0.000000e+00                            0
# 2                2.306364e+09                  23354779585
# 3                         NaN                            0
# 4                0.000000e+00                            0
# 5                0.000000e+00                            0
# 6                6.560292e+09                            0
# 7                0.000000e+00                   1304000000
# 8                0.000000e+00                            0
# 9                1.227000e+07                            0
#
#    Total_-_Grant_Budget_Est_KES  Total_Budget_Supported__by_Donors_KES  \
# 0                    3524395000                             3524395000
# 1                     300000000                              300000000
# 2                    8732081258                            32086860843
# 3                             0                                      0
# 4                      66916163                               66916163
# 5                      46000000                               46000000
# 6                             0                                      0
# 7                             0                             1304000000
# 8                    1351905890                             1351905890
# 9                             0                                      0
#
#    Total_2013/2014_Budget_KES  OBJECTID
# 0                  3524395000         0
# 1                   300000000         1
# 2                 34393225231         2
# 3                           0         3
# 4                    66916163         4
# 5                    46000000         5
# 6                  6560292000         6
# 7                  1304000000         7
# 8                  1351905890         8
# 9                    12270000         9

# %%
# Challenge 12: Government Project Dataset
# Intepolate the missing values in our dataset, noting the changes

# Interpolate missing values in the dataset
gov_dataset.interpolate(method='linear', inplace=True)

# Display the changes
print(gov_dataset.head())
# Out:
#                                  Implementing_Agency  \
# 0                                                NaN
# 1   MOEW&NR  National Environment Management Auth...
# 2   Ministry of Agriculture, Livestock and Fisheries
# 3                                     The Presidency
# 4   MOAL&F  Kenya  Plant Health Inspectorate Serv...
#
#    Total_-_GOK_Budget_Est_KES  Total_-_Loan_Budget_Est_KES  \
# 0                0.000000e+00                            0
# 1                0.000000e+00                            0
# 2                2.306364e+09                  23354779585
# 3                1.153182e+09                            0
# 4                0.000000e+00                            0
#
#    Total_-_Grant_Budget_Est_KES  Total_Budget_Supported__by_Donors_KES  \
# 0                    3524395000                             3524395000
# 1                     300000000                              300000000
# 2                    8732081258                            32086860843
# 3                             0                                      0
# 4                      66916163                               66916163
#
#    Total_2013/2014_Budget_KES  OBJECTID
# 0                  3524395000         0
# 1                   300000000         1
# 2                 34393225231         2
# 3                           0         3
# 4                    66916163         4
# <ipython-input-38-024f4e32267c>:5: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   gov_dataset.interpolate(method='linear', inplace=True)

# %% [markdown]
# **Challenge 13: **Together with your peer discuss the cases where you might use the above interpolate technique.

# %% [markdown]
# ### e) We can drop/delete missing values

# %% [markdown]
# The other way to work with missing data is to drop/delete the records with the missing data. This is a judgement that you have to make based on your research. Sometimes keeping the entire dataset together with the missing values, can leave you with a useless dataset. On the other hand, the missing data many not be random and dropping those missing values would leave you with a biased dataset or deleting the missing dataset might leave you with insufficient data for analysis. All of this we will learn more indepth during the course of the program.
#
# For now lets see how we can drop missing values from a dataset.

# %%
# Challenge 14: Financial Allocation Dataset
# Let's now drop the records that have missing values
fin_dataset = 'http://bit.ly/MSFinancialDataset'

fin_dataset = pd.read_csv('http://bit.ly/MSFinancialDataset')
fin_dataset.head()
# Out:
#                                          NG_Ministry  \
# 0   Ministry of Industialization and Enterprise D...
# 1                      State Department of Transport
# 2                       State Department of planning
# 3                Ministry of Sports Culture and Arts
# 4                              The National Treasury
#
#    GOK_-_Draft_Estimated_KES  GOK_-_Supplementary_Estimated_I__KES  \
# 0               1.020000e+07                          1.881500e+08
# 1               3.200000e+08                          4.000000e+08
# 2               6.827202e+09                          1.608256e+09
# 3                        NaN                                   NaN
# 4               1.300000e+07                          5.400000e+07
#
#    GOK_-_Supplementary_Estimated_II__KES  GOK_-_Off-Budget_Estimated_KES  \
# 0                           0.000000e+00                             0.0
# 1                           6.650000e+09                             0.0
# 2                           0.000000e+00                             0.0
# 3                                    NaN                             NaN
# 4                           0.000000e+00                             0.0
#
#    Total_-_GOK_Budget_Est_KES  Loan_-_Draft_Estimated_KES  \
# 0                   198350000                         NaN
# 1                  7370000000                1.462110e+10
# 2                  8435458686                1.417654e+09
# 3                           0                         NaN
# 4                    67000000                2.168500e+09
#
#    Loan_-_Supplementary_Estimated_I_KES  \
# 0                                   NaN
# 1                          1.478000e+10
# 2                          1.811446e+09
# 3                                   NaN
# 4                          1.729750e+09
#
#    Loan_-_Supplementary_Estimated_II_KES  Loan_-_Off-Budget_Estimated_KES  \
# 0                                    NaN                              NaN
# 1                           1.367470e+10                              0.0
# 2                           1.360906e+09                              0.0
# 3                                    NaN                              NaN
# 4                           1.509570e+09                              0.0
#
#    Total_-_Loan_Budget_Est_KES  Grant_-_Draft_Estimated_KES  \
# 0                            0                 1.452500e+08
# 1                  43075801108                 8.000000e+08
# 2                   4590006224                 1.009631e+10
# 3                            0                 1.270000e+08
# 4                   5407819701                 5.284750e+08
#
#    Grant_-_Supplementary_Estimated_I_KES  \
# 0                           1.347000e+08
# 1                           8.850000e+08
# 2                           1.006256e+10
# 3                           1.270000e+08
# 4                           6.093402e+08
#
#    Grant_-_Supplementary_Estimated_II_KES  Grant_-_Off-Budget_Estimated_KES  \
# 0                            1.347000e+08                               0.0
# 1                            1.007000e+09                               0.0
# 2                            9.208231e+09                               0.0
# 3                            1.270000e+08                               0.0
# 4                            8.421750e+08                               0.0
#
#    Total_-_Grant_Budget_Est_KES  Total_2013/2014_Budget_KES  OBJECTID
# 0                     414650000                   613000000         0
# 1                    2692000000                 53137801108         1
# 2                   29367102979                 42392567889         2
# 3                     381000000                   381000000         3
# 4                    1979990195                  7454809896         4

# %%
fin_dataset.isnull().sum()
# Out:
# NG_Ministry                               0
# GOK_-_Draft_Estimated_KES                 4
# GOK_-_Supplementary_Estimated_I__KES      4
# GOK_-_Supplementary_Estimated_II__KES     4
# GOK_-_Off-Budget_Estimated_KES            4
# Total_-_GOK_Budget_Est_KES                0
# Loan_-_Draft_Estimated_KES                9
# Loan_-_Supplementary_Estimated_I_KES      9
# Loan_-_Supplementary_Estimated_II_KES     9
# Loan_-_Off-Budget_Estimated_KES           9
# Total_-_Loan_Budget_Est_KES               0
# Grant_-_Draft_Estimated_KES               2
# Grant_-_Supplementary_Estimated_I_KES     2
# Grant_-_Supplementary_Estimated_II_KES    2
# Grant_-_Off-Budget_Estimated_KES          2
# Total_-_Grant_Budget_Est_KES              0
# Total_2013/2014_Budget_KES                0
# OBJECTID                                  0
# dtype: int64

# %%
fin_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 18 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   NG_Ministry                             26 non-null     object
#  1   GOK_-_Draft_Estimated_KES               22 non-null     float64
#  2   GOK_-_Supplementary_Estimated_I__KES    22 non-null     float64
#  3   GOK_-_Supplementary_Estimated_II__KES   22 non-null     float64
#  4   GOK_-_Off-Budget_Estimated_KES          22 non-null     float64
#  5   Total_-_GOK_Budget_Est_KES              26 non-null     int64
#  6   Loan_-_Draft_Estimated_KES              17 non-null     float64
#  7   Loan_-_Supplementary_Estimated_I_KES    17 non-null     float64
#  8   Loan_-_Supplementary_Estimated_II_KES   17 non-null     float64
#  9   Loan_-_Off-Budget_Estimated_KES         17 non-null     float64
#  10  Total_-_Loan_Budget_Est_KES             26 non-null     int64
#  11  Grant_-_Draft_Estimated_KES             24 non-null     float64
#  12  Grant_-_Supplementary_Estimated_I_KES   24 non-null     float64
#  13  Grant_-_Supplementary_Estimated_II_KES  24 non-null     float64
#  14  Grant_-_Off-Budget_Estimated_KES        24 non-null     float64
#  15  Total_-_Grant_Budget_Est_KES            26 non-null     int64
#  16  Total_2013/2014_Budget_KES              26 non-null     int64
#  17  OBJECTID                                26 non-null     int64
# dtypes: float64(12), int64(5), object(1)
# memory usage: 3.8+ KB

# %%
fin_dataset.describe()
# Out:
#        GOK_-_Draft_Estimated_KES  GOK_-_Supplementary_Estimated_I__KES  \
# count               2.200000e+01                          2.200000e+01
# mean                3.121857e+09                          1.296687e+09
# std                 6.318664e+09                          3.271493e+09
# min                 0.000000e+00                          0.000000e+00
# 25%                 2.425000e+07                          2.085032e+07
# 50%                 2.641300e+08                          9.425000e+07
# 75%                 1.491249e+09                          1.372969e+09
# max                 2.000000e+10                          1.511600e+10
#
#        GOK_-_Supplementary_Estimated_II__KES  GOK_-_Off-Budget_Estimated_KES  \
# count                           2.200000e+01                    2.200000e+01
# mean                            3.201734e+08                    1.759158e+07
# std                             1.415967e+09                    7.987151e+07
# min                             0.000000e+00                    0.000000e+00
# 25%                             0.000000e+00                    0.000000e+00
# 50%                             0.000000e+00                    0.000000e+00
# 75%                             0.000000e+00                    0.000000e+00
# max                             6.650000e+09                    3.750103e+08
#
#        Total_-_GOK_Budget_Est_KES  Loan_-_Draft_Estimated_KES  \
# count                2.600000e+01                1.700000e+01
# mean                 4.019569e+09                9.059108e+09
# std                  8.125057e+09                1.302980e+10
# min                  0.000000e+00                2.655355e+08
# 25%                  2.425000e+07                1.417654e+09
# 50%                  1.641750e+08                2.266500e+09
# 75%                  2.912946e+09                1.136926e+10
# max                  3.092726e+10                4.153726e+10
#
#        Loan_-_Supplementary_Estimated_I_KES  \
# count                          1.700000e+01
# mean                           9.489136e+09
# std                            1.313401e+10
# min                            3.985514e+08
# 25%                            1.196298e+09
# 50%                            4.919119e+09
# 75%                            1.122178e+10
# max                            4.545304e+10
#
#        Loan_-_Supplementary_Estimated_II_KES  Loan_-_Off-Budget_Estimated_KES  \
# count                           1.700000e+01                             17.0
# mean                            8.268450e+09                              0.0
# std                             1.156591e+10                              0.0
# min                             3.677014e+08                              0.0
# 25%                             1.196298e+09                              0.0
# 50%                             3.729387e+09                              0.0
# 75%                             9.948744e+09                              0.0
# max                             4.341333e+10                              0.0
#
#        Total_-_Loan_Budget_Est_KES  Grant_-_Draft_Estimated_KES  \
# count                 2.600000e+01                 2.400000e+01
# mean                  1.753401e+10                 2.402096e+09
# std                   3.272016e+10                 4.559567e+09
# min                   0.000000e+00                 0.000000e+00
# 25%                   0.000000e+00                 1.409375e+08
# 50%                   3.968063e+09                 8.041115e+08
# 75%                   1.554884e+10                 1.762786e+09
# max                   1.304040e+11                 2.059541e+10
#
#        Grant_-_Supplementary_Estimated_I_KES  \
# count                           2.400000e+01
# mean                            2.829240e+09
# std                             5.305258e+09
# min                             0.000000e+00
# 25%                             1.330250e+08
# 50%                             8.763390e+08
# 75%                             3.105983e+09
# max                             2.365533e+10
#
#        Grant_-_Supplementary_Estimated_II_KES  \
# count                            2.400000e+01
# mean                             1.950803e+09
# std                              3.131818e+09
# min                              0.000000e+00
# 25%                              1.034275e+08
# 50%                              6.735274e+08
# 75%                              2.446355e+09
# max                              1.241479e+10
#
#        Grant_-_Off-Budget_Estimated_KES  Total_-_Grant_Budget_Est_KES  \
# count                      2.400000e+01                  2.600000e+01
# mean                       2.172367e+08                  6.830193e+09
# std                        7.841485e+08                  1.308033e+10
# min                        0.000000e+00                  0.000000e+00
# 25%                        0.000000e+00                  3.117825e+08
# 50%                        0.000000e+00                  2.103622e+09
# 75%                        0.000000e+00                  7.065030e+09
# max                        3.524395e+09                  6.018993e+10
#
#        Total_2013/2014_Budget_KES   OBJECTID
# count                2.600000e+01  26.000000
# mean                 2.838146e+10  12.500000
# std                  4.145570e+10   7.648529
# min                  0.000000e+00   0.000000
# 25%                  7.435453e+08   6.250000
# 50%                  7.250475e+09  12.500000
# 75%                  4.113980e+10  18.750000
# max                  1.547050e+11  25.000000

# %%
# Specify the columns you want to check
columns_with_missing_values = ['GOK_-_Draft_Estimated_KES', 'GOK_-_Supplementary_Estimated_I__KES', 'GOK_-_Supplementary_Estimated_II__KES',
                               'GOK_-_Off-Budget_Estimated_KES','Loan_-_Draft_Estimated_KES', 'Loan_-_Supplementary_Estimated_I_KES',
                               'Loan_-_Supplementary_Estimated_II_KES', 'Loan_-_Off-Budget_Estimated_KES', 'Grant_-_Draft_Estimated_KES',
                               'Grant_-_Supplementary_Estimated_I_KES', 'Grant_-_Supplementary_Estimated_II_KES', 'Grant_-_Off-Budget_Estimated_KES',]

# Count missing values in the selected columns
missing_values_per_column = fin_dataset[columns_with_missing_values].isnull().sum()

print(missing_values_per_column)
# Out:
# GOK_-_Draft_Estimated_KES                 4
# GOK_-_Supplementary_Estimated_I__KES      4
# GOK_-_Supplementary_Estimated_II__KES     4
# GOK_-_Off-Budget_Estimated_KES            4
# Loan_-_Draft_Estimated_KES                9
# Loan_-_Supplementary_Estimated_I_KES      9
# Loan_-_Supplementary_Estimated_II_KES     9
# Loan_-_Off-Budget_Estimated_KES           9
# Grant_-_Draft_Estimated_KES               2
# Grant_-_Supplementary_Estimated_I_KES     2
# Grant_-_Supplementary_Estimated_II_KES    2
# Grant_-_Off-Budget_Estimated_KES          2
# dtype: int64
